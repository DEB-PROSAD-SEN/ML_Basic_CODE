# %%
import pandas as pd
import numpy as np

# %%
credit_card_data=pd.read_csv('E:\\Detasets\\credit_data.csv')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
#distribution of 2 classes
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# this is highly imbalance dataset
# 0->>legit transaction
# 1->>fraudulent Transaction

# %%
legit=credit_card_data[credit_card_data.Class==0]
fraud=credit_card_data[credit_card_data.Class==1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %% [markdown]
# build a sample datasets containing similar distribution of legit and fraudulent transactions

# %%
legit_sample=legit.sample(n=492)
print(legit_sample.shape)
# Out:
# (492, 31)

# %% [markdown]
# concotanate the two dataframe

# %%
new_dataset=pd.concat([legit_sample,fraud],axis=0)
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 201805  134047.0  1.760807 -0.136862 -2.404332  0.847939  0.508814 -0.936006
# 69536    53468.0  1.183157  0.255669  0.385955  1.153673 -0.338083 -0.711352
# 30705    36045.0 -0.007415  0.120814  0.409854 -1.724038 -0.399104  0.721582
# 86649    61332.0  1.032057 -0.840750  0.628993  0.498468 -1.164898 -0.028430
# 34764    37815.0 -3.115607  2.350526 -1.168778 -1.069185  0.655562  4.636670
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 201805  0.449717 -0.264078  0.859983  ... -0.105134 -0.370384 -0.036849
# 69536   0.068933 -0.052266  0.123665  ...  0.062087  0.212513 -0.013310
# 30705  -1.430744 -2.494472  0.960825  ... -1.354875  0.085017 -0.233609
# 86649  -0.661934  0.107310 -0.890666  ... -0.145301 -0.287019 -0.143166
# 34764  -3.452756 -2.939704 -1.259507  ... -2.524628  0.275669  0.246702
#
# ...
